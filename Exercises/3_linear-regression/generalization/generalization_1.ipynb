# %% [markdown]
# #### 1. When can you solve the problem of polynomial regression exactly?

# %% [markdown]
# When the degrees of freedem you have (basically the degree of your polynomial) is greater or equal to the degree of the polynomial that you wanto to fit. This is the case when the degree is $>= n$ where n is the number of points or if our degree is less but the points were generated by a lower order polynomial, then we can just match that one.
